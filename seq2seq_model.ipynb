# %%
import tensorflow as tf
import pickle
import pandas as pd
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.callbacks import EarlyStopping

# %%
# 데이터 로드 (csv 파일 경로에 맞게 수정)
train_data_path = 'C:/deep_learning_project01/cafe_train.csv'
validation_data_path = 'C:/deep_learning_project01/cafe_validation.csv'

train_df = pd.read_csv(train_data_path)
validation_df = pd.read_csv(validation_data_path)

# 데이터에서 질문과 답변 텍스트 분리
train_questions = train_df['q'].values
train_answers = train_df['a'].values
validation_questions = validation_df['q'].values
validation_answers = validation_df['a'].values

train_questions
# Out:
# array(['빙수 위에 뿌려진 과일에서 쉰 냄새가 나는데 어떻게 하면 되죠?', '마카롱 주문했는데 마카롱이 엄청 딱딱해요.',
#        '와플 지금 받았는데 너무 눅눅해서 못먹겠어요 이거 어떻게 하면 되나요?', ...,
#        '모바일상품권도 결제할 수 있어요?', '기프티콘으로 음료 계산할 수 있는 거 맞죠?',
#        '후레쉬크림빵 포인트로 결제할 수 있는거죠?'], dtype=object)

# %%
# 특수 토큰 설정(start, end)
start_token = '<start>'
end_token = '<end>'

# Start/End 토큰을 답변에 추가
train_answers_with_tokens = [start_token + ' ' + ans + ' ' + end_token for ans in train_answers]
validation_answers_with_tokens = [start_token + ' ' + ans + ' ' + end_token for ans in validation_answers]

# 텍스트 토큰화를 위한 Tokenizer 설정
tokenizer = Tokenizer()
#질문과 시작,종료토큰을 추가한 답변데이터를 기반으로 어휘 사전 생성 및 학습
tokenizer.fit_on_texts(train_questions.tolist() + train_answers_with_tokens)
tokenizer.word_index
# Out:
# {'start': 1,
#  'end': 2,
#  '네': 3,
#  '수': 4,
#  '있나요': 5,
#  '있어요': 6,
#  '있습니다': 7,
#  '한': 8,
#  '거': 9,
#  '주세요': 10,
#  '주문': 11,
#  '얼마에요': 12,
#  '아메리카노': 13,
#  '더': 14,
#  '이': 15,
#  '가능합니다': 16,
#  '잔': 17,
#  '마카롱': 18,
#  '얼마예요': 19,
#  '하나': 20,
#  '되나요': 21,
#  '아이스': 22,
#  '두': 23,
#  '입니다': 24,
#  '건가요': 25,
#  '맞죠': 26,
#  '있는': 27,
#  '됩니다': 28,
#  '좀': 29,
#  '아니요': 30,
#  '어떤': 31,
#  '드리겠습니다': 32,
#  '몇': 33,
#  '혹시': 34,
#  '어떻게': 35,
#  '알겠습니다': 36,
#  '지금': 37,
#  '다': 38,
#  '안': 39,
#  '많이': 40,
#  '드릴게요': 41,
#  '추가': 42,
#  '개': 43,
#  '제일': 44,
#  '아이스크림': 45,
#  '얼마인가요': 46,
#  '케이크': 47,
#  '라떼': 48,
#  '가능한가요': 49,
#  '거예요': 50,
#  '결제': 51,
#  '거죠': 52,
#  '주스': 53,
#  '오늘': 54,
#  '다시': 55,
#  '세트': 56,
#  '딸기': 57,
#  '포장': 58,
#  '것': 59,
#  '들어가는': 60,
#  '커피': 61,
#  '쿠키': 62,
#  '총': 63,
#  '걸로': 64,
#  '주문했는데': 65,
#  '여기': 66,
#  '따뜻한': 67,
#  '같이': 68,
#  '잘': 69,
#  '따로': 70,
#  '테이크아웃': 71,
#  '맞습니다': 72,
#  '있을까요': 73,
#  '가격이': 74,
#  '게': 75,
#  '만든': 76,
#  '바로': 77,
#  '들어갑니다': 78,
#  '변경': 79,
#  '초콜릿': 80,
#  '언제': 81,
#  '때': 82,
#  '가장': 83,
#  '도넛': 84,
#  '안에': 85,
#  '맞나요': 86,
#  '건': 87,
#  '다른': 88,
#  '초코': 89,
#  '돼요': 90,
#  '얼마나': 91,
#  '들어간': 92,
#  '음료': 93,
#  '그럼': 94,
#  '취소': 95,
#  '주문한': 96,
#  '바닐라': 97,
#  '정도': 98,
#  '사이즈': 99,
#  '치즈': 100,
#  '중에': 101,
#  '카페라떼': 102,
#  '저희': 103,
#  '시럽': 104,
#  '할게요': 105,
#  '되는': 106,
#  '들어가나요': 107,
#  '도와드리겠습니다': 108,
#  '알려주세요': 109,
#  '말고': 110,
#  '확인': 111,
#  '넣어서': 112,
#  '죄송합니다': 113,
#  '아직': 114,
#  '주문할게요': 115,
#  '샷': 116,
#  '마카롱은': 117,
#  '추가로': 118,
#  '준비해드리겠습니다': 119,
#  '싶은데': 120,
#  '와플': 121,
#  '제가': 122,
#  '주문하면': 123,
#  '없습니다': 124,
#  '직접': 125,
#  '맞아요': 126,
#  '할인': 127,
#  '아이스로': 128,
#  '재고': 129,
#  '떡': 130,
#  '세트에': 131,
#  '빙수': 132,
#  '않습니다': 133,
#  '빵': 134,
#  '뭐가': 135,
#  '해주세요': 136,
#  '모두': 137,
#  '얼마죠': 138,
#  '주실': 139,
#  '먹을': 140,
#  '사이즈로': 141,
#  '아뇨': 142,
#  '얼음': 143,
#  '내일': 144,
#  '큰': 145,
#  '방금': 146,
#  '될까요': 147,
#  '크림': 148,
#  '밀크티': 149,
#  '너무': 150,
#  '맛이': 151,
#  '빼고': 152,
#  '있죠': 153,
#  '주시겠어요': 154,
#  '생크림': 155,
#  '하는데': 156,
#  '부탁드려요': 157,
#  '합니다': 158,
#  '아까': 159,
#  '포장해': 160,
#  '주문할': 161,
#  '메뉴': 162,
#  '콜드브루': 163,
#  '티': 164,
#  '위에': 165,
#  '크리스마스': 166,
#  '하면': 167,
#  '해드릴게요': 168,
#  '건데': 169,
#  '전부': 170,
#  '하나요': 171,
#  '우유': 172,
#  '가격은': 173,
#  '샌드위치': 174,
#  '휘핑크림': 175,
#  '매장에서': 176,
#  '블루베리': 177,
#  '판매하고': 178,
#  '텀블러': 179,
#  '그러면': 180,
#  '세트는': 181,
#  '그냥': 182,
#  '망고': 183,
#  '들어있는': 184,
#  '쿠키는': 185,
#  '들어가요': 186,
#  '추천해': 187,
#  '바꿀': 188,
#  '같은데': 189,
#  '제품': 190,
#  '원': 191,
#  '세': 192,
#  '나온': 193,
#  '케이크는': 194,
#  '인기': 195,
#  '드립니다': 196,
#  '아메리카노에': 197,
#  '주스는': 198,
#  '2개': 199,
#  '요거트': 200,
#  '아메리카노는': 201,
#  '되죠': 202,
#  '그': 203,
#  '원두': 204,
#  '카라멜': 205,
#  '바나나': 206,
#  '가능해요': 207,
#  '인절미': 208,
#  '주시면': 209,
#  '추가해서': 210,
#  '음료는': 211,
#  '같아요': 212,
#  '하나만': 213,
#  '뭔가요': 214,
#  '잔에': 215,
#  '배달': 216,
#  '없나요': 217,
#  '아니오': 218,
#  '사이즈는': 219,
#  '할': 220,
#  '준비해': 221,
#  '아몬드': 222,
#  '헤이즐넛': 223,
#  '녹차': 224,
#  '1개': 225,
#  '담아': 226,
#  '입고': 227,
#  '된': 228,
#  '이거': 229,
#  '넣어': 230,
#  '인기가': 231,
#  '식빵': 232,
#  '가지': 233,
#  '애프터눈': 234,
#  '새로': 235,
#  '준비해드릴게요': 236,
#  '맛': 237,
#  '작은': 238,
#  '과일': 239,
#  '만들어': 240,
#  '조금': 241,
#  '넣어주세요': 242,
#  '얼그레이': 243,
#  '죄송하지만': 244,
#  '칼로리는': 245,
#  '500원': 246,
#  '주스에': 247,
#  '판매': 248,
#  '후': 249,
#  '000원입니다': 250,
#  '추천': 251,
#  '재입고': 252,
#  '000원': 253,
#  '프라푸치노': 254,
#  '없어요': 255,
#  '얼마': 256,
#  '같은': 257,
#  '취소하고': 258,
#  '드실': 259,
#  '흑임자': 260,
#  '드시면': 261,
#  '레몬': 262,
#  '오렌지': 263,
#  '빵은': 264,
#  '주문하신': 265,
#  '구매': 266,
#  '유통기한이': 267,
#  '세트로': 268,
#  '바닐라라떼': 269,
#  '알': 270,
#  '한잔': 271,
#  '2잔': 272,
#  '나오는': 273,
#  '해서': 274,
#  '생과일': 275,
#  '냉동': 276,
#  '좋은': 277,
#  '하겠습니다': 278,
#  '먹어도': 279,
#  '젤라또': 280,
#  '에스프레소': 281,
#  '가격은요': 282,
#  '들어있습니다': 283,
#  '보관': 284,
#  '무슨': 285,
#  '가격': 286,
#  '매장에': 287,
#  '카드': 288,
#  '따뜻하게': 289,
#  '시켰는데': 290,
#  '추가하면': 291,
#  '여기서': 292,
#  '영수증': 293,
#  '라떼는': 294,
#  '커피는': 295,
#  '라떼에': 296,
#  '개당': 297,
#  '남은': 298,
#  '3개': 299,
#  '차가운': 300,
#  '만드는': 301,
#  '10개': 302,
#  '아메리카노로': 303,
#  '어렵습니다': 304,
#  '부탁드립니다': 305,
#  '두유로': 306,
#  '가능한': 307,
#  '국내산': 308,
#  '좋습니다': 309,
#  '시': 310,
#  '선물': 311,
#  '해요': 312,
#  '리필': 313,
#  '뭐예요': 314,
#  '스무디': 315,
#  '키위': 316,
#  '1': 317,
#  '앙버터': 318,
#  '없는': 319,
#  '카드로': 320,
#  '베이글': 321,
#  '어제': 322,
#  '그렇습니다': 323,
#  '싶어요': 324,
#  '하나는': 325,
#  '티라미수': 326,
#  '예정입니다': 327,
#  '카페모카': 328,
#  '캐리어에': 329,
#  '포장해주세요': 330,
#  '중': 331,
#  '사이즈가': 332,
#  '저희는': 333,
#  '사용합니다': 334,
#  '추가할': 335,
#  '들어': 336,
#  '포장되나요': 337,
#  '해드리겠습니다': 338,
#  '만듭니다': 339,
#  '변경할': 340,
#  '사이즈업': 341,
#  '살': 342,
#  '도넛은': 343,
#  '넣어드릴게요': 344,
#  '제품은': 345,
#  '디카페인': 346,
#  '추가는': 347,
#  '아침에': 348,
#  '초콜릿은': 349,
#  '먹고': 350,
#  '11월': 351,
#  '찹쌀떡': 352,
#  '오리지널': 353,
#  '1잔': 354,
#  '그럼요': 355,
#  '박스에': 356,
#  '사면': 357,
#  '백설기': 358,
#  '라떼로': 359,
#  '이번': 360,
#  '마카롱이': 361,
#  '있는데': 362,
#  '사용하고': 363,
#  '박스': 364,
#  '칼로리가': 365,
#  '하시면': 366,
#  '종류가': 367,
#  '받았습니다': 368,
#  '원하시는': 369,
#  '떡은': 370,
#  '나옵니다': 371,
#  '취소해': 372,
#  '뜨거운': 373,
#  '알려주시겠어요': 374,
#  '냉장': 375,
#  '하는': 376,
#  '매일': 377,
#  '재고가': 378,
#  '구성되어': 379,
#  '주시는': 380,
#  '스콘': 381,
#  '어느': 382,
#  '만들고': 383,
#  '담아서': 384,
#  '카푸치노': 385,
#  '다섯': 386,
#  '이미': 387,
#  '저': 388,
#  '우유를': 389,
#  '판매합니다': 390,
#  '같습니다': 391,
#  '메뉴가': 392,
#  '디카페인으로': 393,
#  '들어있어요': 394,
#  '현재': 395,
#  '5개': 396,
#  '도와드릴게요': 397,
#  '모카': 398,
#  '주실래요': 399,
#  '현금으로': 400,
#  '했는데': 401,
#  '하나씩': 402,
#  '메뉴는': 403,
#  '일회용': 404,
#  '포장해드리겠습니다': 405,
#  '함께': 406,
#  '카페': 407,
#  '냉장고에': 408,
#  '5': 409,
#  '연유': 410,
#  '카페인': 411,
#  '아이스크림은': 412,
#  '유통기한은': 413,
#  '재결제': 414,
#  '경우': 415,
#  '품절입니다': 416,
#  '들어있나요': 417,
#  '시즌': 418,
#  '원산지가': 419,
#  '세트에는': 420,
#  '겁니다': 421,
#  '일반': 422,
#  '보관해도': 423,
#  '하고': 424,
#  '추가해': 425,
#  '추가해주세요': 426,
#  '그린티': 427,
#  '하나랑': 428,
#  '주문받았습니다': 429,
#  '가능할까요': 430,
#  '머핀': 431,
#  '원두는': 432,
#  '나가는': 433,
#  '나오나요': 434,
#  '전에': 435,
#  '종류': 436,
#  '아': 437,
#  '냉동실에': 438,
#  '자몽': 439,
#  '많은': 440,
#  '허니브레드': 441,
#  '하나에': 442,
#  '뭐': 443,
#  '유통기한': 444,
#  '넣고': 445,
#  '중에서': 446,
#  '라지': 447,
#  '4': 448,
#  '제품입니다': 449,
#  '불가능합니다': 450,
#  '크림치즈': 451,
#  '실키': 452,
#  '해당': 453,
#  '에이드': 454,
#  '주문했던': 455,
#  '잔은': 456,
#  '예': 457,
#  '추천해주세요': 458,
#  '다크': 459,
#  '조각': 460,
#  '고객님': 461,
#  '걸': 462,
#  '오래': 463,
#  '청포도': 464,
#  '종류는': 465,
#  '않고': 466,
#  '화이트': 467,
#  '있습니까': 468,
#  '맛으로': 469,
#  '추가할게요': 470,
#  '원산지는': 471,
#  '현금영수증': 472,
#  '확인해': 473,
#  '펄': 474,
#  '못': 475,
#  '주문하고': 476,
#  '출시': 477,
#  '포장하면': 478,
#  '설탕': 479,
#  '그렇게': 480,
#  '빙수에': 481,
#  '주문이': 482,
#  '바꿔주세요': 483,
#  '딸기라떼': 484,
#  '가능하죠': 485,
#  '결제할게요': 486,
#  '해': 487,
#  '나와요': 488,
#  '먹어야': 489,
#  '결제는': 490,
#  '당도': 491,
#  '드려요': 492,
#  '들어가지': 493,
#  '얼마입니까': 494,
#  '맛을': 495,
#  '커피가': 496,
#  '치즈케이크': 497,
#  '주시나요': 498,
#  '포함되어': 499,
#  '매장': 500,
#  '보관하면': 501,
#  '남아': 502,
#  '시키면': 503,
#  '오늘은': 504,
#  '차': 505,
#  '500원입니다': 506,
#  '잘못': 507,
#  '케이크가': 508,
#  '시럽은': 509,
#  '홍차': 510,
#  '때문에': 511,
#  '칼로리': 512,
#  '바꿔드릴게요': 513,
#  '나갑니다': 514,
#  '바꿔서': 515,
#  '남아있습니다': 516,
#  '주문하시면': 517,
#  '쿠키가': 518,
#  '뭐에요': 519,
#  '팥': 520,
#  '카페라떼에': 521,
#  '선택': 522,
#  '모든': 523,
#  '3': 524,
#  '조금만': 525,
#  '만들': 526,
#  '1000원': 527,
#  '민트': 528,
#  '밀크': 529,
#  '케익': 530,
#  '포장해서': 531,
#  '기본': 532,
#  '없이': 533,
#  '번': 534,
#  '원래': 535,
#  '토핑': 536,
#  '구매하면': 537,
#  '플레인': 538,
#  '3잔': 539,
#  '떡케이크': 540,
#  '좋아요': 541,
#  '12월': 542,
#  '죄송합니다만': 543,
#  '비용': 544,
#  '시원한': 545,
#  '오전에': 546,
#  '왜': 547,
#  '주신': 548,
#  '얼음은': 549,
#  '선택할': 550,
#  '고를': 551,
#  '저희가': 552,
#  '블랙': 553,
#  '포장됩니다': 554,
#  '이렇게': 555,
#  '주스로': 556,
#  '베스트': 557,
#  '2': 558,
#  '맛은': 559,
#  '드셔도': 560,
#  '드리도록': 561,
#  '나는': 562,
#  '커피를': 563,
#  '현금': 564,
#  '테이크아웃으로': 565,
#  '육천': 566,
#  '사과': 567,
#  '어디': 568,
#  '티는': 569,
#  '데워서': 570,
#  '버터': 571,
#  '파인애플': 572,
#  '들어가': 573,
#  '원두를': 574,
#  '10': 575,
#  '또': 576,
#  '변경해서': 577,
#  '빨리': 578,
#  '전자레인지에': 579,
#  '가능하십니다': 580,
#  '입고됩니다': 581,
#  '이건': 582,
#  '할로윈': 583,
#  '먹으면': 584,
#  '생딸기': 585,
#  '포장은': 586,
#  '시럽을': 587,
#  '자바칩': 588,
#  '잠시만': 589,
#  '메뉴입니다': 590,
#  '드라이아이스': 591,
#  '둘': 592,
#  '사용해서': 593,
#  '나눠서': 594,
#  '아닙니다': 595,
#  '거의': 596,
#  '롤케이크': 597,
#  '양이': 598,
#  '언제까지': 599,
#  '맛있어요': 600,
#  '밀크티는': 601,
#  '알려주실래요': 602,
#  '와플은': 603,
#  '알고': 604,
#  '괜찮습니다': 605,
#  '구성': 606,
#  '핫': 607,
#  '잔만': 608,
#  '취소해주세요': 609,
#  '이상': 610,
#  '변경해': 611,
#  '진짜': 612,
#  '될': 613,
#  '가능하세요': 614,
#  '아닌가요': 615,
#  '바게트': 616,
#  '넣은': 617,
#  '판매하는': 618,
#  '핫으로': 619,
#  '카카오': 620,
#  '갈아서': 621,
#  '구성이': 622,
#  '추가해드리겠습니다': 623,
#  '취소해드리겠습니다': 624,
#  '포장할': 625,
#  '각각': 626,
#  '쏙': 627,
#  '달지': 628,
#  '밀크티에': 629,
#  '텀블러에': 630,
#  '샌드위치는': 631,
#  '다음': 632,
#  '불가합니다': 633,
#  '보시면': 634,
#  '거에요': 635,
#  '좋을까요': 636,
#  '달고나': 637,
#  '요즘': 638,
#  '않은': 639,
#  '변경해드리겠습니다': 640,
#  '두개': 641,
#  '컵에': 642,
#  '넣어드리겠습니다': 643,
#  '않아요': 644,
#  '우유로': 645,
#  '마카롱을': 646,
#  '먼저': 647,
#  '원이요': 648,
#  '넣어주실': 649,
#  '되는지': 650,
#  '시나몬': 651,
#  '크로플': 652,
#  '줘요': 653,
#  '나가요': 654,
#  '올스타': 655,
#  '든': 656,
#  '흑당': 657,
#  '바닐라맛': 658,
#  '만드시는': 659,
#  '유기농': 660,
#  '제주': 661,
#  '드시는': 662,
#  '상온에': 663,
#  '원입니다': 664,
#  '낱개로': 665,
#  '구운': 666,
#  '생과일주스': 667,
#  '대신': 668,
#  '홀리데이': 669,
#  '넣어드려요': 670,
#  '토피넛라떼': 671,
#  '인가요': 672,
#  '식빵은': 673,
#  '당근': 674,
#  '아인슈페너': 675,
#  '컵': 676,
#  '팔리는': 677,
#  '드셔야': 678,
#  '올라가는': 679,
#  '부탁드릴게요': 680,
#  '우유는': 681,
#  '상자에': 682,
#  '취소할게요': 683,
#  '데워': 684,
#  '구매하실': 685,
#  '보관하시면': 686,
#  '구매할': 687,
#  '해도': 688,
#  '물': 689,
#  '물티슈': 690,
#  '포장해드릴게요': 691,
#  '맛있습니다': 692,
#  '결제해': 693,
#  '먹는': 694,
#  '아이스크림이': 695,
#  '해주실': 696,
#  '그대로': 697,
#  '것이': 698,
#  '4개': 699,
#  '토스트': 700,
#  '아이스크림으로': 701,
#  '가능하나요': 702,
#  '몽블랑': 703,
#  '있게': 704,
#  '덜': 705,
#  '토핑은': 706,
#  '땅콩': 707,
#  '말차': 708,
#  '10분': 709,
#  '보통': 710,
#  '냉장보관': 711,
#  '도넛이': 712,
#  '돌체라떼': 713,
#  '금방': 714,
#  '중입니다': 715,
#  '넣지': 716,
#  '맛있게': 717,
#  '그리고': 718,
#  '최대': 719,
#  '프랑스산': 720,
#  '인기있는': 721,
#  '수제': 722,
#  '아니에요': 723,
#  '꼭': 724,
#  '에디션': 725,
#  '취소할': 726,
#  '차이가': 727,
#  '봉투에': 728,
#  '있는지': 729,
#  '제품으로': 730,
#  '빙수는': 731,
#  '차는': 732,
#  '파나요': 733,
#  '주로': 734,
#  '만들었습니다': 735,
#  '크림이': 736,
#  '빵이': 737,
#  '커피에': 738,
#  '주스가': 739,
#  '무료로': 740,
#  '포장도': 741,
#  '것도': 742,
#  '오후': 743,
#  '브런치': 744,
#  '주문하려고': 745,
#  '있어서': 746,
#  '고구마': 747,
#  '레귤러': 748,
#  '에그': 749,
#  '빨대': 750,
#  '대로': 751,
#  '냉동고에': 752,
#  '넣을': 753,
#  '차갑게': 754,
#  '스트로베리': 755,
#  '결제할': 756,
#  '함량이': 757,
#  '말씀해': 758,
#  '괜찮아요': 759,
#  '처리': 760,
#  '주문하실': 761,
#  '뭐죠': 762,
#  '수박': 763,
#  '더블': 764,
#  '라즈베리': 765,
#  '계산': 766,
#  '음료가': 767,
#  '칩': 768,
#  '좋을': 769,
#  '약': 770,
#  '변경할게요': 771,
#  '쓰고': 772,
#  '결제해드리겠습니다': 773,
#  '단호박': 774,
#  '아예': 775,
#  '두잔': 776,
#  '출시된': 777,
#  '바꿀게요': 778,
#  '슈크림': 779,
#  '후에': 780,
#  '구매하시면': 781,
#  '씁니다': 782,
#  '아메리카노를': 783,
#  '따라': 784,
#  '선물용으로': 785,
#  '원두로': 786,
#  '녹차라떼': 787,
#  '담아주세요': 788,
#  '드리고': 789,
#  '준비되어': 790,
#  '타르트': 791,
#  '타피오카': 792,
#  '수량': 793,
#  '세트에서': 794,
#  '제조': 795,
#  '아이스티': 796,
#  '종류별로': 797,
#  '추가해드릴게요': 798,
#  '많습니다': 799,
#  '들어옵니다': 800,
#  '제품이': 801,
#  '토피넛': 802,
#  '쇼콜라': 803,
#  '핫초코': 804,
#  '금액': 805,
#  '어디에': 806,
#  '어떤가요': 807,
#  '실온에': 808,
#  '추가됩니다': 809,
#  '4500원입니다': 810,
#  '개씩': 811,
#  '파는': 812,
#  '치즈가': 813,
#  '토마토': 814,
#  '매장은': 815,
#  '구성된': 816,
#  '시간이': 817,
#  '그런데': 818,
#  '마카롱에': 819,
#  '내야': 820,
#  '먹기': 821,
#  '베이글은': 822,
#  '미트': 823,
#  '드릴': 824,
#  '확인해보겠습니다': 825,
#  '건지': 826,
#  '샐러드': 827,
#  '얼마인지': 828,
#  '추가하고': 829,
#  '아이들이': 830,
#  '좋아하는': 831,
#  '레드벨벳': 832,
#  '카페라떼는': 833,
#  '구성은': 834,
#  '괜찮은': 835,
#  '마들렌': 836,
#  '아침': 837,
#  '당일': 838,
#  '할부': 839,
#  '휘핑': 840,
#  '파이': 841,
#  '담아드릴게요': 842,
#  '케이크에': 843,
#  '해야': 844,
#  '만드신': 845,
#  '아닌': 846,
#  '소시지빵': 847,
#  '오레오': 848,
#  '밤': 849,
#  '100': 850,
#  '기프티콘으로': 851,
#  '오븐에': 852,
#  '변경해주세요': 853,
#  '품절되었습니다': 854,
#  '추천드립니다': 855,
#  '빵에': 856,
#  '얼음을': 857,
#  '결제한': 858,
#  '포장이': 859,
#  '알려주실': 860,
#  '그건': 861,
#  '가래떡': 862,
#  '포인트': 863,
#  '됩니까': 864,
#  '초콜릿을': 865,
#  '디저트': 866,
#  '다쿠아즈': 867,
#  '머랭': 868,
#  '오늘의': 869,
#  '결제해주세요': 870,
#  '용량이': 871,
#  '많아요': 872,
#  '데': 873,
#  '싶은데요': 874,
#  '시럽이': 875,
#  '아이스아메리카노': 876,
#  '아메리카노랑': 877,
#  '만들어요': 878,
#  '담아드리겠습니다': 879,
#  '팩': 880,
#  '지금은': 881,
#  '어디서': 882,
#  '나왔어요': 883,
#  '떡이': 884,
#  '오전': 885,
#  '국산': 886,
#  '사용하는': 887,
#  '톨': 888,
#  '판매하나요': 889,
#  '부드러운': 890,
#  '넣어주시는': 891,
#  '생크림이': 892,
#  '그러는데': 893,
#  '금액은': 894,
#  '실온': 895,
#  '사천': 896,
#  '아메리카노가': 897,
#  '샌드위치에': 898,
#  '빼': 899,
#  '선물용': 900,
#  '없을까요': 901,
#  '팔아요': 902,
#  '포함된': 903,
#  '케익은': 904,
#  '품절인가요': 905,
#  '정말': 906,
#  '연유라떼': 907,
#  '미니': 908,
#  '파인트': 909,
#  '가득': 910,
#  '멤버십': 911,
#  '일시불로': 912,
#  '원이에요': 913,
#  '바꿔드리겠습니다': 914,
#  '스콘은': 915,
#  '4잔': 916,
#  '한라봉': 917,
#  '할부로': 918,
#  '3500원': 919,
#  '않게': 920,
#  '만한': 921,
#  '오시면': 922,
#  '판매하지': 923,
#  '들어와요': 924,
#  '다른가요': 925,
#  '마시고': 926,
#  '음료를': 927,
#  '것은': 928,
#  '휘핑크림은': 929,
#  '딸기는': 930,
#  '메뉴로': 931,
#  '크림은': 932,
#  '냅킨': 933,
#  '보관해야': 934,
#  '변경이': 935,
#  '빼주세요': 936,
#  '딸기바나나': 937,
#  '초코칩': 938,
#  '초코라떼': 939,
#  '추가한': 940,
#  '쿠폰': 941,
#  '수도': 942,
#  '안에는': 943,
#  '단': 944,
#  '갈': 945,
#  '수플레': 946,
#  '커피도': 947,
#  '엄마는': 948,
#  '받고': 949,
#  '상한': 950,
#  '코코넛': 951,
#  '들어오나요': 952,
#  '하죠': 953,
#  '견과류': 954,
#  '콘으로': 955,
#  '그란데': 956,
#  '돌체': 957,
#  '받을': 958,
#  '잔이랑': 959,
#  '먼치킨': 960,
#  '레몬에이드': 961,
#  '한정': 962,
#  '맞습니까': 963,
#  '페스츄리': 964,
#  '남았어요': 965,
#  '우유가': 966,
#  '판매하시나요': 967,
#  '고구마라떼': 968,
#  '복숭아': 969,
#  '와플에': 970,
#  '버블': 971,
#  '10월': 972,
#  '송편': 973,
#  '딸기맛으로': 974,
#  '기본으로': 975,
#  '상품입니다': 976,
#  '올라갑니다': 977,
#  '3000원입니다': 978,
#  '적게': 979,
#  '바꿔': 980,
#  '딸기주스': 981,
#  '틴케이스에': 982,
#  '할인이': 983,
#  '초콜릿이': 984,
#  '주': 985,
#  '원하는': 986,
#  '5900원이에요': 987,
#  '제품인가요': 988,
#  '선물세트': 989,
#  '쓰는': 990,
#  '있으면': 991,
#  '케이크로': 992,
#  '같아서': 993,
#  '주문해도': 994,
#  '떡으로': 995,
#  '바나나주스': 996,
#  '선택하실': 997,
#  '변경하실': 998,
#  '6900원이에요': 999,
#  '만들어진': 1000,
#  ...}

# %%
# 생성한 어휘사전을 통해 텍스트를 시퀀스로 변환
train_questions_seq = tokenizer.texts_to_sequences(train_questions)
train_answers_seq = tokenizer.texts_to_sequences(train_answers_with_tokens)
validation_questions_seq = tokenizer.texts_to_sequences(validation_questions)
validation_answers_seq = tokenizer.texts_to_sequences(validation_answers_with_tokens)

# %%
# 패딩 처리 (각각 질문과 답변의 최대 길이에 맞춰 패딩)
#각 질문과 답변 데이터중 가장 긴 시퀀스 길이
max_len_q = max(len(seq) for seq in train_questions_seq)
max_len_a = max(len(seq) for seq in train_answers_seq)
#post-padding방식으로 시퀀스길이를 최대 길이에 맞춤
train_questions_padded = pad_sequences(train_questions_seq, maxlen=max_len_q, padding='post')
train_answers_padded = pad_sequences(train_answers_seq, maxlen=max_len_a, padding='post')
validation_questions_padded = pad_sequences(validation_questions_seq, maxlen=max_len_q, padding='post')
validation_answers_padded = pad_sequences(validation_answers_seq, maxlen=max_len_a, padding='post')

# 단어 집합 크기 계산
vocab_size = len(tokenizer.word_index) + 1  # 패딩 토큰을 고려하여 +1

# 데이터셋 전처리 상태 확인
print({
    "vocab_size": vocab_size,
    "max_len_q": max_len_q,
    "max_len_a": max_len_a,
    "train_sample_shape": train_questions_padded.shape
})
# Out:
# {'vocab_size': 42436, 'max_len_q': 21, 'max_len_a': 36, 'train_sample_shape': (54922, 21)}

# %%
# 모델 하이퍼파라미터 설정
embedding_dim = 256  # 임베딩 차원
latent_dim = 512  # LSTM의 잠재 차원

# 인코더 설정
encoder_inputs = Input(shape=(None,), name='encoder_inputs')
#mask_zer=True -> 패딩을 통해 추가된 0을 무시함
encoder_embedding = Embedding(input_dim=vocab_size, output_dim=embedding_dim, mask_zero=True)(encoder_inputs)
encoder_lstm, state_h, state_c = LSTM(latent_dim, return_state=True, name='encoder_lstm')(encoder_embedding)
encoder_states = [state_h, state_c]

# 디코더 설정
decoder_inputs = Input(shape=(None,), name='decoder_inputs')
decoder_embedding = Embedding(input_dim=vocab_size, output_dim=embedding_dim, mask_zero=True)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True, name='decoder_lstm')
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(vocab_size, activation='softmax', name='decoder_dense')
decoder_outputs = decoder_dense(decoder_outputs)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# 모델 컴파일
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 모델 구조 확인
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  decoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  embedding (Embedding)          (None, None, 256)    10863616    ['encoder_inputs[0][0]']
#
#  embedding_1 (Embedding)        (None, None, 256)    10863616    ['decoder_inputs[0][0]']
#
#  encoder_lstm (LSTM)            [(None, 512),        1574912     ['embedding[0][0]']
#                                  (None, 512),
#                                  (None, 512)]
#
#  decoder_lstm (LSTM)            [(None, None, 512),  1574912     ['embedding_1[0][0]',
#                                  (None, 512),                     'encoder_lstm[0][1]',
#                                  (None, 512)]                     'encoder_lstm[0][2]']
#
#  decoder_dense (Dense)          (None, None, 42436)  21769668    ['decoder_lstm[0][0]']
#
# ==================================================================================================
# Total params: 46,646,724
# Trainable params: 46,646,724
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 디코더 출력은 정답 시퀀스에서 오른쪽으로 한 칸씩 이동한 값이 필요
train_answers_shifted = train_answers_padded[:, 1:]  # 마지막 한 칸을 제외한 시퀀스
train_answers_padded = train_answers_padded[:, :-1]  # 처음 한 칸을 제외한 시퀀스


early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# 모델 훈련
batch_size = 64
epochs = 30

history = model.fit(
    [train_questions_padded, train_answers_padded],  # 인코더 입력과 디코더 입력
    train_answers_shifted,  # 디코더 출력
    batch_size=batch_size,
    epochs=epochs,
    validation_data=([validation_questions_padded, validation_answers_padded[:, :-1]], validation_answers_padded[:, 1:]),  # 검증 데이터
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/30
# 859/859 [==============================] - 66s 70ms/step - loss: 0.9053 - accuracy: 0.4036 - val_loss: 0.8488 - val_accuracy: 0.4211
# Epoch 2/30
# 859/859 [==============================] - 59s 68ms/step - loss: 0.7140 - accuracy: 0.4611 - val_loss: 0.7530 - val_accuracy: 0.4531
# Epoch 3/30
# 859/859 [==============================] - 60s 70ms/step - loss: 0.5970 - accuracy: 0.4969 - val_loss: 0.6909 - val_accuracy: 0.4793
# Epoch 4/30
# 859/859 [==============================] - 61s 71ms/step - loss: 0.4929 - accuracy: 0.5343 - val_loss: 0.6561 - val_accuracy: 0.4957
# Epoch 5/30
# 859/859 [==============================] - 61s 71ms/step - loss: 0.4003 - accuracy: 0.5784 - val_loss: 0.6400 - val_accuracy: 0.5080
# Epoch 6/30
# 859/859 [==============================] - 64s 75ms/step - loss: 0.3194 - accuracy: 0.6349 - val_loss: 0.6357 - val_accuracy: 0.5174
# Epoch 7/30
# 859/859 [==============================] - 62s 72ms/step - loss: 0.2524 - accuracy: 0.6968 - val_loss: 0.6354 - val_accuracy: 0.5248
# Epoch 8/30
# 859/859 [==============================] - 61s 72ms/step - loss: 0.2001 - accuracy: 0.7503 - val_loss: 0.6416 - val_accuracy: 0.5308
# Epoch 9/30
# 859/859 [==============================] - 64s 74ms/step - loss: 0.1589 - accuracy: 0.7987 - val_loss: 0.6536 - val_accuracy: 0.5351
# Epoch 10/30
# 859/859 [==============================] - 63s 73ms/step - loss: 0.1259 - accuracy: 0.8399 - val_loss: 0.6653 - val_accuracy: 0.5341
# Epoch 11/30
# 859/859 [==============================] - 63s 73ms/step - loss: 0.0997 - accuracy: 0.8733 - val_loss: 0.6799 - val_accuracy: 0.5373
# Epoch 12/30
# 859/859 [==============================] - 63s 73ms/step - loss: 0.0787 - accuracy: 0.9010 - val_loss: 0.6937 - val_accuracy: 0.5365

# %%
encoder_model = Model(encoder_inputs, encoder_states)

# 디코더 모델 구성
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_embedding, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# %%
# 모델 저장
model.save('C:/deep_learning_project01/seq2seq_model/seq2seq_model.h5')
encoder_model.save('C:/deep_learning_project01/seq2seq_model/seq2seq_encoder_model.h5')
decoder_model.save('C:/deep_learning_project01/seq2seq_model/seq2seq_decoder_model.h5')

# Tokenizer 저장
with open('C:/deep_learning_project01/seq2seq_model/tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# max_len_q와 max_len_a 값을 파일로 저장
with open('C:/deep_learning_project01/attention/seq2seq_max_len_q.pickle', 'wb') as f:
    pickle.dump(max_len_q, f)

with open('C:/deep_learning_project01/attention/seq2seq_max_len_a.pickle', 'wb') as f:
    pickle.dump(max_len_a, f)
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
model2 = tf.keras.models.load_model('C:/deep_learning_project01/seq2seq_model/seq2seq_model.h5')

# %%
model2.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  encoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  decoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  embedding (Embedding)          (None, None, 256)    10863616    ['encoder_inputs[0][0]']
#
#  embedding_1 (Embedding)        (None, None, 256)    10863616    ['decoder_inputs[0][0]']
#
#  encoder_lstm (LSTM)            [(None, 512),        1574912     ['embedding[0][0]']
#                                  (None, 512),
#                                  (None, 512)]
#
#  decoder_lstm (LSTM)            [(None, None, 512),  1574912     ['embedding_1[0][0]',
#                                  (None, 512),                     'encoder_lstm[0][1]',
#                                  (None, 512)]                     'encoder_lstm[0][2]']
#
#  decoder_dense (Dense)          (None, None, 42436)  21769668    ['decoder_lstm[0][0]']
#
# ==================================================================================================
# Total params: 46,646,724
# Trainable params: 46,646,724
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
encoder_model2 = tf.keras.models.load_model('C:/deep_learning_project01/seq2seq_model/seq2seq_encoder_model.h5')
decoder_model2 = tf.keras.models.load_model('C:/deep_learning_project01/seq2seq_model/seq2seq_decoder_model.h5')
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
encoder_model2.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  encoder_inputs (InputLayer)  [(None, None)]           0
#
#  embedding (Embedding)       (None, None, 256)         10863616
#
#  encoder_lstm (LSTM)         [(None, 512),             1574912
#                               (None, 512),
#                               (None, 512)]
#
# =================================================================
# Total params: 12,438,528
# Trainable params: 12,438,528
# Non-trainable params: 0
# _________________________________________________________________

# %%
decoder_model2.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  decoder_inputs (InputLayer)    [(None, None)]       0           []
#
#  embedding_1 (Embedding)        (None, None, 256)    10863616    ['decoder_inputs[0][0]']
#
#  input_1 (InputLayer)           [(None, 512)]        0           []
#
#  input_2 (InputLayer)           [(None, 512)]        0           []
#
#  decoder_lstm (LSTM)            [(None, None, 512),  1574912     ['embedding_1[0][0]',
#                                  (None, 512),                     'input_1[0][0]',
#                                  (None, 512)]                     'input_2[0][0]']
#
#  decoder_dense (Dense)          (None, None, 42436)  21769668    ['decoder_lstm[0][0]']
#
# ==================================================================================================
# Total params: 34,208,196
# Trainable params: 34,208,196
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
tokenizer2 = None
max_len_a2 = None
max_len_q2 = None

with open('C:/deep_learning_project01/seq2seq_model/tokenizer.pickle', 'rb') as handle:
    tokenizer2 = pickle.load(handle)

with open('C:/deep_learning_project01/attention/seq2seq_max_len_q.pickle', 'rb') as handle:
    max_len_q2 = pickle.load(handle)

with open('C:/deep_learning_project01/attention/seq2seq_max_len_a.pickle', 'rb') as handle:
    max_len_a2 = pickle.load(handle) 

print(max_len_a2)
print(max_len_q2)
# Out:
# 36
# 21

# %%
tokenizer2.word_index
# Out:
# {'start': 1,
#  'end': 2,
#  '네': 3,
#  '수': 4,
#  '있나요': 5,
#  '있어요': 6,
#  '있습니다': 7,
#  '한': 8,
#  '거': 9,
#  '주세요': 10,
#  '주문': 11,
#  '얼마에요': 12,
#  '아메리카노': 13,
#  '더': 14,
#  '이': 15,
#  '가능합니다': 16,
#  '잔': 17,
#  '마카롱': 18,
#  '얼마예요': 19,
#  '하나': 20,
#  '되나요': 21,
#  '아이스': 22,
#  '두': 23,
#  '입니다': 24,
#  '건가요': 25,
#  '맞죠': 26,
#  '있는': 27,
#  '됩니다': 28,
#  '좀': 29,
#  '아니요': 30,
#  '어떤': 31,
#  '드리겠습니다': 32,
#  '몇': 33,
#  '혹시': 34,
#  '어떻게': 35,
#  '알겠습니다': 36,
#  '지금': 37,
#  '다': 38,
#  '안': 39,
#  '많이': 40,
#  '드릴게요': 41,
#  '추가': 42,
#  '개': 43,
#  '제일': 44,
#  '아이스크림': 45,
#  '얼마인가요': 46,
#  '케이크': 47,
#  '라떼': 48,
#  '가능한가요': 49,
#  '거예요': 50,
#  '결제': 51,
#  '거죠': 52,
#  '주스': 53,
#  '오늘': 54,
#  '다시': 55,
#  '세트': 56,
#  '딸기': 57,
#  '포장': 58,
#  '것': 59,
#  '들어가는': 60,
#  '커피': 61,
#  '쿠키': 62,
#  '총': 63,
#  '걸로': 64,
#  '주문했는데': 65,
#  '여기': 66,
#  '따뜻한': 67,
#  '같이': 68,
#  '잘': 69,
#  '따로': 70,
#  '테이크아웃': 71,
#  '맞습니다': 72,
#  '있을까요': 73,
#  '가격이': 74,
#  '게': 75,
#  '만든': 76,
#  '바로': 77,
#  '들어갑니다': 78,
#  '변경': 79,
#  '초콜릿': 80,
#  '언제': 81,
#  '때': 82,
#  '가장': 83,
#  '도넛': 84,
#  '안에': 85,
#  '맞나요': 86,
#  '건': 87,
#  '다른': 88,
#  '초코': 89,
#  '돼요': 90,
#  '얼마나': 91,
#  '들어간': 92,
#  '음료': 93,
#  '그럼': 94,
#  '취소': 95,
#  '주문한': 96,
#  '바닐라': 97,
#  '정도': 98,
#  '사이즈': 99,
#  '치즈': 100,
#  '중에': 101,
#  '카페라떼': 102,
#  '저희': 103,
#  '시럽': 104,
#  '할게요': 105,
#  '되는': 106,
#  '들어가나요': 107,
#  '도와드리겠습니다': 108,
#  '알려주세요': 109,
#  '말고': 110,
#  '확인': 111,
#  '넣어서': 112,
#  '죄송합니다': 113,
#  '아직': 114,
#  '주문할게요': 115,
#  '샷': 116,
#  '마카롱은': 117,
#  '추가로': 118,
#  '준비해드리겠습니다': 119,
#  '싶은데': 120,
#  '와플': 121,
#  '제가': 122,
#  '주문하면': 123,
#  '없습니다': 124,
#  '직접': 125,
#  '맞아요': 126,
#  '할인': 127,
#  '아이스로': 128,
#  '재고': 129,
#  '떡': 130,
#  '세트에': 131,
#  '빙수': 132,
#  '않습니다': 133,
#  '빵': 134,
#  '뭐가': 135,
#  '해주세요': 136,
#  '모두': 137,
#  '얼마죠': 138,
#  '주실': 139,
#  '먹을': 140,
#  '사이즈로': 141,
#  '아뇨': 142,
#  '얼음': 143,
#  '내일': 144,
#  '큰': 145,
#  '방금': 146,
#  '될까요': 147,
#  '크림': 148,
#  '밀크티': 149,
#  '너무': 150,
#  '맛이': 151,
#  '빼고': 152,
#  '있죠': 153,
#  '주시겠어요': 154,
#  '생크림': 155,
#  '하는데': 156,
#  '부탁드려요': 157,
#  '합니다': 158,
#  '아까': 159,
#  '포장해': 160,
#  '주문할': 161,
#  '메뉴': 162,
#  '콜드브루': 163,
#  '티': 164,
#  '위에': 165,
#  '크리스마스': 166,
#  '하면': 167,
#  '해드릴게요': 168,
#  '건데': 169,
#  '전부': 170,
#  '하나요': 171,
#  '우유': 172,
#  '가격은': 173,
#  '샌드위치': 174,
#  '휘핑크림': 175,
#  '매장에서': 176,
#  '블루베리': 177,
#  '판매하고': 178,
#  '텀블러': 179,
#  '그러면': 180,
#  '세트는': 181,
#  '그냥': 182,
#  '망고': 183,
#  '들어있는': 184,
#  '쿠키는': 185,
#  '들어가요': 186,
#  '추천해': 187,
#  '바꿀': 188,
#  '같은데': 189,
#  '제품': 190,
#  '원': 191,
#  '세': 192,
#  '나온': 193,
#  '케이크는': 194,
#  '인기': 195,
#  '드립니다': 196,
#  '아메리카노에': 197,
#  '주스는': 198,
#  '2개': 199,
#  '요거트': 200,
#  '아메리카노는': 201,
#  '되죠': 202,
#  '그': 203,
#  '원두': 204,
#  '카라멜': 205,
#  '바나나': 206,
#  '가능해요': 207,
#  '인절미': 208,
#  '주시면': 209,
#  '추가해서': 210,
#  '음료는': 211,
#  '같아요': 212,
#  '하나만': 213,
#  '뭔가요': 214,
#  '잔에': 215,
#  '배달': 216,
#  '없나요': 217,
#  '아니오': 218,
#  '사이즈는': 219,
#  '할': 220,
#  '준비해': 221,
#  '아몬드': 222,
#  '헤이즐넛': 223,
#  '녹차': 224,
#  '1개': 225,
#  '담아': 226,
#  '입고': 227,
#  '된': 228,
#  '이거': 229,
#  '넣어': 230,
#  '인기가': 231,
#  '식빵': 232,
#  '가지': 233,
#  '애프터눈': 234,
#  '새로': 235,
#  '준비해드릴게요': 236,
#  '맛': 237,
#  '작은': 238,
#  '과일': 239,
#  '만들어': 240,
#  '조금': 241,
#  '넣어주세요': 242,
#  '얼그레이': 243,
#  '죄송하지만': 244,
#  '칼로리는': 245,
#  '500원': 246,
#  '주스에': 247,
#  '판매': 248,
#  '후': 249,
#  '000원입니다': 250,
#  '추천': 251,
#  '재입고': 252,
#  '000원': 253,
#  '프라푸치노': 254,
#  '없어요': 255,
#  '얼마': 256,
#  '같은': 257,
#  '취소하고': 258,
#  '드실': 259,
#  '흑임자': 260,
#  '드시면': 261,
#  '레몬': 262,
#  '오렌지': 263,
#  '빵은': 264,
#  '주문하신': 265,
#  '구매': 266,
#  '유통기한이': 267,
#  '세트로': 268,
#  '바닐라라떼': 269,
#  '알': 270,
#  '한잔': 271,
#  '2잔': 272,
#  '나오는': 273,
#  '해서': 274,
#  '생과일': 275,
#  '냉동': 276,
#  '좋은': 277,
#  '하겠습니다': 278,
#  '먹어도': 279,
#  '젤라또': 280,
#  '에스프레소': 281,
#  '가격은요': 282,
#  '들어있습니다': 283,
#  '보관': 284,
#  '무슨': 285,
#  '가격': 286,
#  '매장에': 287,
#  '카드': 288,
#  '따뜻하게': 289,
#  '시켰는데': 290,
#  '추가하면': 291,
#  '여기서': 292,
#  '영수증': 293,
#  '라떼는': 294,
#  '커피는': 295,
#  '라떼에': 296,
#  '개당': 297,
#  '남은': 298,
#  '3개': 299,
#  '차가운': 300,
#  '만드는': 301,
#  '10개': 302,
#  '아메리카노로': 303,
#  '어렵습니다': 304,
#  '부탁드립니다': 305,
#  '두유로': 306,
#  '가능한': 307,
#  '국내산': 308,
#  '좋습니다': 309,
#  '시': 310,
#  '선물': 311,
#  '해요': 312,
#  '리필': 313,
#  '뭐예요': 314,
#  '스무디': 315,
#  '키위': 316,
#  '1': 317,
#  '앙버터': 318,
#  '없는': 319,
#  '카드로': 320,
#  '베이글': 321,
#  '어제': 322,
#  '그렇습니다': 323,
#  '싶어요': 324,
#  '하나는': 325,
#  '티라미수': 326,
#  '예정입니다': 327,
#  '카페모카': 328,
#  '캐리어에': 329,
#  '포장해주세요': 330,
#  '중': 331,
#  '사이즈가': 332,
#  '저희는': 333,
#  '사용합니다': 334,
#  '추가할': 335,
#  '들어': 336,
#  '포장되나요': 337,
#  '해드리겠습니다': 338,
#  '만듭니다': 339,
#  '변경할': 340,
#  '사이즈업': 341,
#  '살': 342,
#  '도넛은': 343,
#  '넣어드릴게요': 344,
#  '제품은': 345,
#  '디카페인': 346,
#  '추가는': 347,
#  '아침에': 348,
#  '초콜릿은': 349,
#  '먹고': 350,
#  '11월': 351,
#  '찹쌀떡': 352,
#  '오리지널': 353,
#  '1잔': 354,
#  '그럼요': 355,
#  '박스에': 356,
#  '사면': 357,
#  '백설기': 358,
#  '라떼로': 359,
#  '이번': 360,
#  '마카롱이': 361,
#  '있는데': 362,
#  '사용하고': 363,
#  '박스': 364,
#  '칼로리가': 365,
#  '하시면': 366,
#  '종류가': 367,
#  '받았습니다': 368,
#  '원하시는': 369,
#  '떡은': 370,
#  '나옵니다': 371,
#  '취소해': 372,
#  '뜨거운': 373,
#  '알려주시겠어요': 374,
#  '냉장': 375,
#  '하는': 376,
#  '매일': 377,
#  '재고가': 378,
#  '구성되어': 379,
#  '주시는': 380,
#  '스콘': 381,
#  '어느': 382,
#  '만들고': 383,
#  '담아서': 384,
#  '카푸치노': 385,
#  '다섯': 386,
#  '이미': 387,
#  '저': 388,
#  '우유를': 389,
#  '판매합니다': 390,
#  '같습니다': 391,
#  '메뉴가': 392,
#  '디카페인으로': 393,
#  '들어있어요': 394,
#  '현재': 395,
#  '5개': 396,
#  '도와드릴게요': 397,
#  '모카': 398,
#  '주실래요': 399,
#  '현금으로': 400,
#  '했는데': 401,
#  '하나씩': 402,
#  '메뉴는': 403,
#  '일회용': 404,
#  '포장해드리겠습니다': 405,
#  '함께': 406,
#  '카페': 407,
#  '냉장고에': 408,
#  '5': 409,
#  '연유': 410,
#  '카페인': 411,
#  '아이스크림은': 412,
#  '유통기한은': 413,
#  '재결제': 414,
#  '경우': 415,
#  '품절입니다': 416,
#  '들어있나요': 417,
#  '시즌': 418,
#  '원산지가': 419,
#  '세트에는': 420,
#  '겁니다': 421,
#  '일반': 422,
#  '보관해도': 423,
#  '하고': 424,
#  '추가해': 425,
#  '추가해주세요': 426,
#  '그린티': 427,
#  '하나랑': 428,
#  '주문받았습니다': 429,
#  '가능할까요': 430,
#  '머핀': 431,
#  '원두는': 432,
#  '나가는': 433,
#  '나오나요': 434,
#  '전에': 435,
#  '종류': 436,
#  '아': 437,
#  '냉동실에': 438,
#  '자몽': 439,
#  '많은': 440,
#  '허니브레드': 441,
#  '하나에': 442,
#  '뭐': 443,
#  '유통기한': 444,
#  '넣고': 445,
#  '중에서': 446,
#  '라지': 447,
#  '4': 448,
#  '제품입니다': 449,
#  '불가능합니다': 450,
#  '크림치즈': 451,
#  '실키': 452,
#  '해당': 453,
#  '에이드': 454,
#  '주문했던': 455,
#  '잔은': 456,
#  '예': 457,
#  '추천해주세요': 458,
#  '다크': 459,
#  '조각': 460,
#  '고객님': 461,
#  '걸': 462,
#  '오래': 463,
#  '청포도': 464,
#  '종류는': 465,
#  '않고': 466,
#  '화이트': 467,
#  '있습니까': 468,
#  '맛으로': 469,
#  '추가할게요': 470,
#  '원산지는': 471,
#  '현금영수증': 472,
#  '확인해': 473,
#  '펄': 474,
#  '못': 475,
#  '주문하고': 476,
#  '출시': 477,
#  '포장하면': 478,
#  '설탕': 479,
#  '그렇게': 480,
#  '빙수에': 481,
#  '주문이': 482,
#  '바꿔주세요': 483,
#  '딸기라떼': 484,
#  '가능하죠': 485,
#  '결제할게요': 486,
#  '해': 487,
#  '나와요': 488,
#  '먹어야': 489,
#  '결제는': 490,
#  '당도': 491,
#  '드려요': 492,
#  '들어가지': 493,
#  '얼마입니까': 494,
#  '맛을': 495,
#  '커피가': 496,
#  '치즈케이크': 497,
#  '주시나요': 498,
#  '포함되어': 499,
#  '매장': 500,
#  '보관하면': 501,
#  '남아': 502,
#  '시키면': 503,
#  '오늘은': 504,
#  '차': 505,
#  '500원입니다': 506,
#  '잘못': 507,
#  '케이크가': 508,
#  '시럽은': 509,
#  '홍차': 510,
#  '때문에': 511,
#  '칼로리': 512,
#  '바꿔드릴게요': 513,
#  '나갑니다': 514,
#  '바꿔서': 515,
#  '남아있습니다': 516,
#  '주문하시면': 517,
#  '쿠키가': 518,
#  '뭐에요': 519,
#  '팥': 520,
#  '카페라떼에': 521,
#  '선택': 522,
#  '모든': 523,
#  '3': 524,
#  '조금만': 525,
#  '만들': 526,
#  '1000원': 527,
#  '민트': 528,
#  '밀크': 529,
#  '케익': 530,
#  '포장해서': 531,
#  '기본': 532,
#  '없이': 533,
#  '번': 534,
#  '원래': 535,
#  '토핑': 536,
#  '구매하면': 537,
#  '플레인': 538,
#  '3잔': 539,
#  '떡케이크': 540,
#  '좋아요': 541,
#  '12월': 542,
#  '죄송합니다만': 543,
#  '비용': 544,
#  '시원한': 545,
#  '오전에': 546,
#  '왜': 547,
#  '주신': 548,
#  '얼음은': 549,
#  '선택할': 550,
#  '고를': 551,
#  '저희가': 552,
#  '블랙': 553,
#  '포장됩니다': 554,
#  '이렇게': 555,
#  '주스로': 556,
#  '베스트': 557,
#  '2': 558,
#  '맛은': 559,
#  '드셔도': 560,
#  '드리도록': 561,
#  '나는': 562,
#  '커피를': 563,
#  '현금': 564,
#  '테이크아웃으로': 565,
#  '육천': 566,
#  '사과': 567,
#  '어디': 568,
#  '티는': 569,
#  '데워서': 570,
#  '버터': 571,
#  '파인애플': 572,
#  '들어가': 573,
#  '원두를': 574,
#  '10': 575,
#  '또': 576,
#  '변경해서': 577,
#  '빨리': 578,
#  '전자레인지에': 579,
#  '가능하십니다': 580,
#  '입고됩니다': 581,
#  '이건': 582,
#  '할로윈': 583,
#  '먹으면': 584,
#  '생딸기': 585,
#  '포장은': 586,
#  '시럽을': 587,
#  '자바칩': 588,
#  '잠시만': 589,
#  '메뉴입니다': 590,
#  '드라이아이스': 591,
#  '둘': 592,
#  '사용해서': 593,
#  '나눠서': 594,
#  '아닙니다': 595,
#  '거의': 596,
#  '롤케이크': 597,
#  '양이': 598,
#  '언제까지': 599,
#  '맛있어요': 600,
#  '밀크티는': 601,
#  '알려주실래요': 602,
#  '와플은': 603,
#  '알고': 604,
#  '괜찮습니다': 605,
#  '구성': 606,
#  '핫': 607,
#  '잔만': 608,
#  '취소해주세요': 609,
#  '이상': 610,
#  '변경해': 611,
#  '진짜': 612,
#  '될': 613,
#  '가능하세요': 614,
#  '아닌가요': 615,
#  '바게트': 616,
#  '넣은': 617,
#  '판매하는': 618,
#  '핫으로': 619,
#  '카카오': 620,
#  '갈아서': 621,
#  '구성이': 622,
#  '추가해드리겠습니다': 623,
#  '취소해드리겠습니다': 624,
#  '포장할': 625,
#  '각각': 626,
#  '쏙': 627,
#  '달지': 628,
#  '밀크티에': 629,
#  '텀블러에': 630,
#  '샌드위치는': 631,
#  '다음': 632,
#  '불가합니다': 633,
#  '보시면': 634,
#  '거에요': 635,
#  '좋을까요': 636,
#  '달고나': 637,
#  '요즘': 638,
#  '않은': 639,
#  '변경해드리겠습니다': 640,
#  '두개': 641,
#  '컵에': 642,
#  '넣어드리겠습니다': 643,
#  '않아요': 644,
#  '우유로': 645,
#  '마카롱을': 646,
#  '먼저': 647,
#  '원이요': 648,
#  '넣어주실': 649,
#  '되는지': 650,
#  '시나몬': 651,
#  '크로플': 652,
#  '줘요': 653,
#  '나가요': 654,
#  '올스타': 655,
#  '든': 656,
#  '흑당': 657,
#  '바닐라맛': 658,
#  '만드시는': 659,
#  '유기농': 660,
#  '제주': 661,
#  '드시는': 662,
#  '상온에': 663,
#  '원입니다': 664,
#  '낱개로': 665,
#  '구운': 666,
#  '생과일주스': 667,
#  '대신': 668,
#  '홀리데이': 669,
#  '넣어드려요': 670,
#  '토피넛라떼': 671,
#  '인가요': 672,
#  '식빵은': 673,
#  '당근': 674,
#  '아인슈페너': 675,
#  '컵': 676,
#  '팔리는': 677,
#  '드셔야': 678,
#  '올라가는': 679,
#  '부탁드릴게요': 680,
#  '우유는': 681,
#  '상자에': 682,
#  '취소할게요': 683,
#  '데워': 684,
#  '구매하실': 685,
#  '보관하시면': 686,
#  '구매할': 687,
#  '해도': 688,
#  '물': 689,
#  '물티슈': 690,
#  '포장해드릴게요': 691,
#  '맛있습니다': 692,
#  '결제해': 693,
#  '먹는': 694,
#  '아이스크림이': 695,
#  '해주실': 696,
#  '그대로': 697,
#  '것이': 698,
#  '4개': 699,
#  '토스트': 700,
#  '아이스크림으로': 701,
#  '가능하나요': 702,
#  '몽블랑': 703,
#  '있게': 704,
#  '덜': 705,
#  '토핑은': 706,
#  '땅콩': 707,
#  '말차': 708,
#  '10분': 709,
#  '보통': 710,
#  '냉장보관': 711,
#  '도넛이': 712,
#  '돌체라떼': 713,
#  '금방': 714,
#  '중입니다': 715,
#  '넣지': 716,
#  '맛있게': 717,
#  '그리고': 718,
#  '최대': 719,
#  '프랑스산': 720,
#  '인기있는': 721,
#  '수제': 722,
#  '아니에요': 723,
#  '꼭': 724,
#  '에디션': 725,
#  '취소할': 726,
#  '차이가': 727,
#  '봉투에': 728,
#  '있는지': 729,
#  '제품으로': 730,
#  '빙수는': 731,
#  '차는': 732,
#  '파나요': 733,
#  '주로': 734,
#  '만들었습니다': 735,
#  '크림이': 736,
#  '빵이': 737,
#  '커피에': 738,
#  '주스가': 739,
#  '무료로': 740,
#  '포장도': 741,
#  '것도': 742,
#  '오후': 743,
#  '브런치': 744,
#  '주문하려고': 745,
#  '있어서': 746,
#  '고구마': 747,
#  '레귤러': 748,
#  '에그': 749,
#  '빨대': 750,
#  '대로': 751,
#  '냉동고에': 752,
#  '넣을': 753,
#  '차갑게': 754,
#  '스트로베리': 755,
#  '결제할': 756,
#  '함량이': 757,
#  '말씀해': 758,
#  '괜찮아요': 759,
#  '처리': 760,
#  '주문하실': 761,
#  '뭐죠': 762,
#  '수박': 763,
#  '더블': 764,
#  '라즈베리': 765,
#  '계산': 766,
#  '음료가': 767,
#  '칩': 768,
#  '좋을': 769,
#  '약': 770,
#  '변경할게요': 771,
#  '쓰고': 772,
#  '결제해드리겠습니다': 773,
#  '단호박': 774,
#  '아예': 775,
#  '두잔': 776,
#  '출시된': 777,
#  '바꿀게요': 778,
#  '슈크림': 779,
#  '후에': 780,
#  '구매하시면': 781,
#  '씁니다': 782,
#  '아메리카노를': 783,
#  '따라': 784,
#  '선물용으로': 785,
#  '원두로': 786,
#  '녹차라떼': 787,
#  '담아주세요': 788,
#  '드리고': 789,
#  '준비되어': 790,
#  '타르트': 791,
#  '타피오카': 792,
#  '수량': 793,
#  '세트에서': 794,
#  '제조': 795,
#  '아이스티': 796,
#  '종류별로': 797,
#  '추가해드릴게요': 798,
#  '많습니다': 799,
#  '들어옵니다': 800,
#  '제품이': 801,
#  '토피넛': 802,
#  '쇼콜라': 803,
#  '핫초코': 804,
#  '금액': 805,
#  '어디에': 806,
#  '어떤가요': 807,
#  '실온에': 808,
#  '추가됩니다': 809,
#  '4500원입니다': 810,
#  '개씩': 811,
#  '파는': 812,
#  '치즈가': 813,
#  '토마토': 814,
#  '매장은': 815,
#  '구성된': 816,
#  '시간이': 817,
#  '그런데': 818,
#  '마카롱에': 819,
#  '내야': 820,
#  '먹기': 821,
#  '베이글은': 822,
#  '미트': 823,
#  '드릴': 824,
#  '확인해보겠습니다': 825,
#  '건지': 826,
#  '샐러드': 827,
#  '얼마인지': 828,
#  '추가하고': 829,
#  '아이들이': 830,
#  '좋아하는': 831,
#  '레드벨벳': 832,
#  '카페라떼는': 833,
#  '구성은': 834,
#  '괜찮은': 835,
#  '마들렌': 836,
#  '아침': 837,
#  '당일': 838,
#  '할부': 839,
#  '휘핑': 840,
#  '파이': 841,
#  '담아드릴게요': 842,
#  '케이크에': 843,
#  '해야': 844,
#  '만드신': 845,
#  '아닌': 846,
#  '소시지빵': 847,
#  '오레오': 848,
#  '밤': 849,
#  '100': 850,
#  '기프티콘으로': 851,
#  '오븐에': 852,
#  '변경해주세요': 853,
#  '품절되었습니다': 854,
#  '추천드립니다': 855,
#  '빵에': 856,
#  '얼음을': 857,
#  '결제한': 858,
#  '포장이': 859,
#  '알려주실': 860,
#  '그건': 861,
#  '가래떡': 862,
#  '포인트': 863,
#  '됩니까': 864,
#  '초콜릿을': 865,
#  '디저트': 866,
#  '다쿠아즈': 867,
#  '머랭': 868,
#  '오늘의': 869,
#  '결제해주세요': 870,
#  '용량이': 871,
#  '많아요': 872,
#  '데': 873,
#  '싶은데요': 874,
#  '시럽이': 875,
#  '아이스아메리카노': 876,
#  '아메리카노랑': 877,
#  '만들어요': 878,
#  '담아드리겠습니다': 879,
#  '팩': 880,
#  '지금은': 881,
#  '어디서': 882,
#  '나왔어요': 883,
#  '떡이': 884,
#  '오전': 885,
#  '국산': 886,
#  '사용하는': 887,
#  '톨': 888,
#  '판매하나요': 889,
#  '부드러운': 890,
#  '넣어주시는': 891,
#  '생크림이': 892,
#  '그러는데': 893,
#  '금액은': 894,
#  '실온': 895,
#  '사천': 896,
#  '아메리카노가': 897,
#  '샌드위치에': 898,
#  '빼': 899,
#  '선물용': 900,
#  '없을까요': 901,
#  '팔아요': 902,
#  '포함된': 903,
#  '케익은': 904,
#  '품절인가요': 905,
#  '정말': 906,
#  '연유라떼': 907,
#  '미니': 908,
#  '파인트': 909,
#  '가득': 910,
#  '멤버십': 911,
#  '일시불로': 912,
#  '원이에요': 913,
#  '바꿔드리겠습니다': 914,
#  '스콘은': 915,
#  '4잔': 916,
#  '한라봉': 917,
#  '할부로': 918,
#  '3500원': 919,
#  '않게': 920,
#  '만한': 921,
#  '오시면': 922,
#  '판매하지': 923,
#  '들어와요': 924,
#  '다른가요': 925,
#  '마시고': 926,
#  '음료를': 927,
#  '것은': 928,
#  '휘핑크림은': 929,
#  '딸기는': 930,
#  '메뉴로': 931,
#  '크림은': 932,
#  '냅킨': 933,
#  '보관해야': 934,
#  '변경이': 935,
#  '빼주세요': 936,
#  '딸기바나나': 937,
#  '초코칩': 938,
#  '초코라떼': 939,
#  '추가한': 940,
#  '쿠폰': 941,
#  '수도': 942,
#  '안에는': 943,
#  '단': 944,
#  '갈': 945,
#  '수플레': 946,
#  '커피도': 947,
#  '엄마는': 948,
#  '받고': 949,
#  '상한': 950,
#  '코코넛': 951,
#  '들어오나요': 952,
#  '하죠': 953,
#  '견과류': 954,
#  '콘으로': 955,
#  '그란데': 956,
#  '돌체': 957,
#  '받을': 958,
#  '잔이랑': 959,
#  '먼치킨': 960,
#  '레몬에이드': 961,
#  '한정': 962,
#  '맞습니까': 963,
#  '페스츄리': 964,
#  '남았어요': 965,
#  '우유가': 966,
#  '판매하시나요': 967,
#  '고구마라떼': 968,
#  '복숭아': 969,
#  '와플에': 970,
#  '버블': 971,
#  '10월': 972,
#  '송편': 973,
#  '딸기맛으로': 974,
#  '기본으로': 975,
#  '상품입니다': 976,
#  '올라갑니다': 977,
#  '3000원입니다': 978,
#  '적게': 979,
#  '바꿔': 980,
#  '딸기주스': 981,
#  '틴케이스에': 982,
#  '할인이': 983,
#  '초콜릿이': 984,
#  '주': 985,
#  '원하는': 986,
#  '5900원이에요': 987,
#  '제품인가요': 988,
#  '선물세트': 989,
#  '쓰는': 990,
#  '있으면': 991,
#  '케이크로': 992,
#  '같아서': 993,
#  '주문해도': 994,
#  '떡으로': 995,
#  '바나나주스': 996,
#  '선택하실': 997,
#  '변경하실': 998,
#  '6900원이에요': 999,
#  '만들어진': 1000,
#  ...}

# %%
# 디코딩 함수에서 예측
def decode_sequence(input_seq):
    # 인코더 상태 추출
    states_value = encoder_model2.predict(input_seq)
    
    # <start> 토큰으로 시작하는 타겟 시퀀스
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = tokenizer2.word_index['start']
    
    stop_condition = False
    decoded_sentence = ''
    
    while not stop_condition:
        output_tokens, h, c = decoder_model2.predict([target_seq] + states_value)
        
        # 예측된 토큰을 텍스트로 변환
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_word = tokenizer2.index_word.get(sampled_token_index, '')
        decoded_sentence += ' ' + sampled_word
        
        # <end> 토큰을 만나거나 일정 길이를 넘으면 중단
        if (sampled_word == 'end' or len(decoded_sentence) > max_len_a2):
            stop_condition = True
        
        # 타겟 시퀀스 업데이트 (다음 단계 예측을 위해)
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index
        
        # 상태 업데이트
        states_value = [h, c]
    
    return decoded_sentence

# %%
import numpy as np
# 예시 질문
input_question = "빨때는 빼고 줘"  # 새로운 질문 입력
input_seq = tokenizer2.texts_to_sequences([input_question])
input_seq = pad_sequences(input_seq, maxlen=max_len_q2, padding='post')

# 예측
predicted_sentence = decode_sequence(input_seq)

print(f"질문: {input_question}")
print(f"예측된 답변: {predicted_sentence}")
# Out:
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 1s 585ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 질문: 빨때는 빼고 줘
# 예측된 답변:  네 고객님 end
